# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder

# %%
compras_df = pd.read_csv('C:/Users/HP/Documents/IA/data/clean_compras.csv')

# %%
data=compras_df.copy()

# %% [markdown]
# ## Llenar los valores faltantes del dataframe

# %%
#utiliza el for con un indice para en una lista almacenar el tipo de dato en cadena
for i, column in enumerate(list([str(d) for d in data.dtypes])):
    #si el tipo de dato es object
    if column == "object":
        data[data.columns[i]] = data[data.columns[i]].fillna(data[data.columns[i]].mode())
        data[data.columns[i]] = data[data.columns[i]].astype("category").cat.codes
    else:
        data[data.columns[i]] = data[data.columns[i]].fillna(data[data.columns[i]].median())

# %%
data.head(5)
# Out:
#       C B  BENEFICIARIO   RFC  FACTURA  CONTRATO  CONCEPTO  TIPO      FDO-#OP  \
# 0  123803           373   385    16851      5184     13840     1    1025275.0
# 1  206273          2055  1924      979        26      7992     1    1025278.0
# 2  206273          2055  1924      980        26      7993     1    1025279.0
# 3  206273          2055  1924     1576        26     10456     1  332000144.0
# 4  206273          2055  1924     1578        26     10453     1  332000145.0
#
#    FECHA    IMPORTE  SHEET  Mes
# 0      1  389093.21      7    3
# 1      1    6564.00      7    3
# 2      1    6418.00      7    3
# 3      1  110220.65      7    3
# 4      1  400123.00      7    3

# %%
data.dtypes
# Out:
# C B               int64
# BENEFICIARIO      int16
# RFC               int16
# FACTURA           int16
# CONTRATO          int16
# CONCEPTO          int16
# TIPO               int8
# FDO-#OP         float64
# FECHA             int16
# IMPORTE         float64
# SHEET              int8
# Mes                int8
# dtype: object

# %% [markdown]
# ## Utilizar random forest

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score

# %%
y = data.pop('IMPORTE')
X = data.copy()

# %% [markdown]
# ## Dividir los datos en dos grupos

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
clf = RandomForestRegressor(n_estimators=1000, max_depth = 4)

# %%
clf.fit(X_train,y_train)
# Out:
# RandomForestRegressor(max_depth=4, n_estimators=1000)

# %%
r2_score(y_test, clf.predict(X_test))
# Out:
# 0.06437403198672986

# %% [markdown]
# ## modelo no supervisado

# %%
import warnings
warnings.filterwarnings("ignore",category=UserWarning,module="sklearn")
from sklearn.cluster import KMeans

# %%
df_copy=compras_df.copy()

# %%
df_copy.head(3)
# Out:
#       C B                                    BENEFICIARIO           RFC  \
# 0  123803  COLEGIO DE INGENIEROS CIVILES DE NUEVO LEON AC  CIC710521SA1
# 1  206273                      TESORERIA DE LA FEDERACION  SAT970701NN3
# 2  206273                      TESORERIA DE LA FEDERACION  SAT970701NN3
#
#               FACTURA      CONTRATO  \
# 0     P 1214-185004-4  SIS-172-2022
# 1  124000760-183001-8     NO APLICA
# 2  124000771-183001-7     NO APLICA
#
#                                             CONCEPTO TIPO    FDO-#OP  \
# 0  RP-2023 30% ANT. SRSIS-RP-06/22-IR 1)LEV. TOPO...   TR  1025275.0
# 1  PAGO DE DERECHOS A FAVOR DE LA SECRETARIA DE I...   TR  1025278.0
# 2  PAGO DE DERECHOS A FAVOR DE LA SRIA. DE INFRAE...   TR  1025279.0
#
#         FECHA    IMPORTE                        SHEET    Mes
# 0  2023-01-30  389093.21  OBRA PUBLICA Y GV FDOS. ESP  Enero
# 1  2023-01-30    6564.00  OBRA PUBLICA Y GV FDOS. ESP  Enero
# 2  2023-01-30    6418.00  OBRA PUBLICA Y GV FDOS. ESP  Enero

# %%
df_copy.dtypes
# Out:
# C B               int64
# BENEFICIARIO     object
# RFC              object
# FACTURA          object
# CONTRATO         object
# CONCEPTO         object
# TIPO             object
# FDO-#OP         float64
# FECHA            object
# IMPORTE         float64
# SHEET            object
# Mes              object
# dtype: object

# %%
# Se consideran las varibales CB, CONTRATO,IMPORTE, FACTURA
columns_to_drop = ['BENEFICIARIO', 'CONCEPTO', 'Mes', 'SHEET','RFC','TIPO','FDO-#OP','FECHA']
df_copy = df_copy.drop(columns=columns_to_drop)
df_copy
# Out:
#           C B             FACTURA      CONTRATO    IMPORTE
# 0      123803     P 1214-185004-4  SIS-172-2022  389093.21
# 1      206273  124000760-183001-8     NO APLICA    6564.00
# 2      206273  124000771-183001-7     NO APLICA    6418.00
# 3      206273            183006-1     NO APLICA  110220.65
# 4      206273            183006-2     NO APLICA  400123.00
# ...       ...                 ...           ...        ...
# 17525  203016  103992-183010-2632     NO APLICA    2064.20
# 17526  203016  103992-183010-2763     NO APLICA    2064.20
# 17527  203016  103992-183010-2739     NO APLICA    2064.20
# 17528  203016  104651-183010-2529     NO APLICA    5563.47
# 17529  203016    1149-183010-2659     NO APLICA   28427.56
#
# [17530 rows x 4 columns]

# %%
for i, column in enumerate(list([str(d) for d in df_copy.dtypes])):
    if column == "object":
        df_copy[df_copy.columns[i]] = df_copy[df_copy.columns[i]].fillna(df_copy[df_copy.columns[i]].mode()[0])
        df_copy[df_copy.columns[i]] = df_copy[df_copy.columns[i]].astype("category").cat.codes
    else:
        df_copy[df_copy.columns[i]] = df_copy[df_copy.columns[i]].fillna(df_copy[df_copy.columns[i]].median())

# %%
df_copy.dtypes
# Out:
# C B           int64
# FACTURA       int16
# CONTRATO      int16
# IMPORTE     float64
# dtype: object

# %%
df_copy
# Out:
#           C B  FACTURA  CONTRATO    IMPORTE
# 0      123803    16851      5184  389093.21
# 1      206273      979        26    6564.00
# 2      206273      980        26    6418.00
# 3      206273     1576        26  110220.65
# 4      206273     1578        26  400123.00
# ...       ...      ...       ...        ...
# 17525  203016      205        26    2064.20
# 17526  203016      208        26    2064.20
# 17527  203016      207        26    2064.20
# 17528  203016      231        26    5563.47
# 17529  203016      669        26   28427.56
#
# [17530 rows x 4 columns]

# %%
# normalizar
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
normalized_data = scaler.fit_transform(df_copy)
df_nor = pd.DataFrame(normalized_data, columns=df_copy.columns)
df_nor
# Out:
#             C B   FACTURA  CONTRATO   IMPORTE
# 0      0.015469  0.965839  0.938111  0.003838
# 1      0.108136  0.056113  0.004705  0.000065
# 2      0.108136  0.056170  0.004705  0.000063
# 3      0.108136  0.090331  0.004705  0.001087
# 4      0.108136  0.090445  0.004705  0.003947
# ...         ...       ...       ...       ...
# 17525  0.104476  0.011750  0.004705  0.000020
# 17526  0.104476  0.011922  0.004705  0.000020
# 17527  0.104476  0.011865  0.004705  0.000020
# 17528  0.104476  0.013240  0.004705  0.000055
# 17529  0.104476  0.038345  0.004705  0.000280
#
# [17530 rows x 4 columns]

# %%
wcss = []

# Iteramos numeros de clusters de 1 a 10
for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, max_iter=100, random_state=1)
    kmeans.fit(df_nor)  
    wcss.append(kmeans.inertia_)

# %%
# Graficar Elbow 
plt.plot(range(1, 11), wcss)
plt.title('Codo')
plt.xlabel('Número de Clusters')
plt.ylabel('WCSS')  
plt.show()

# %%
clustering = KMeans(n_clusters=4, max_iter=300, random_state=42)
clustering.fit(df_nor)
df_copy['kmeans_c']=clustering.labels_
df_copy['kmeans_c'].value_counts()
# Out:
# kmeans_c
# 0    6240
# 3    4589
# 1    4288
# 2    2413
# Name: count, dtype: int64

# %%
# Aplicamos PCA 2 dimensiones
pca=PCA(n_components=2)
pca_com=pca.fit_transform(df_nor)
pca_com_df=pd.DataFrame(data=pca_com,columns=['componente_1','componente_2'])
pca_nom_bene=pd.concat([pca_com_df,df_copy['kmeans_c']],axis=1)
pca_nom_bene
# Out:
#        componente_1  componente_2  kmeans_c
# 0          0.517989      0.267579         0
# 1         -0.714352     -0.156025         1
# 2         -0.714327     -0.155973         1
# 3         -0.699778     -0.125071         1
# 4         -0.699728     -0.124969         1
# ...             ...           ...       ...
# 17525     -0.733231     -0.196233         1
# 17526     -0.733157     -0.196078         1
# 17527     -0.733182     -0.196130         1
# 17528     -0.732596     -0.194885         1
# 17529     -0.721904     -0.172176         1
#
# [17530 rows x 3 columns]

# %%
plt.figure(figsize=(10, 8))

scatter = plt.scatter(
    pca_nom_bene['componente_1'], 
    pca_nom_bene['componente_2'], 
    c=pca_nom_bene['kmeans_c'], 
    cmap='viridis', 
    s=100, 
    alpha=0.7
)
plt.title('Clusters formados mediante KMeans y PCA')
plt.xlabel('Componente 1')
plt.ylabel('Componente 2')

lege=plt.legend(*scatter.legend_elements(),title='Clusters')
plt.gca().add_artist(lege)
